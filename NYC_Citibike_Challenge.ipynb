# %%
import pandas as pd
import os

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data. 
pwd = os.getcwd()
citi_bike_data = os.path.join(pwd, "201908-citibike-tripdata.csv")
citi_bike_df = pd.read_csv(citi_bike_data)
citi_bike_df.sample(5)
# Out:
#          tripduration                 starttime                  stoptime  \
# 2280930          1291  2019-08-31 00:51:12.7790  2019-08-31 01:12:44.7280
# 1102354           115  2019-08-15 10:26:41.9840  2019-08-15 10:28:37.1150
# 1867910           720  2019-08-25 16:55:50.6340  2019-08-25 17:07:51.5570
# 1727762           615  2019-08-23 18:06:25.2630  2019-08-23 18:16:40.6510
# 814917           2295  2019-08-11 15:59:49.8510  2019-08-11 16:38:05.2680
#
#          start station id             start station name  \
# 2280930             405.0  Washington St & Gansevoort St
# 1102354            3049.0       Cambridge Pl & Gates Ave
# 1867910             496.0                E 16 St & 5 Ave
# 1727762             528.0                2 Ave & E 31 St
# 814917             3486.0      Schermerhorn St & Bond St
#
#          start station latitude  start station longitude  end station id  \
# 2280930               40.739323               -74.008119           401.0
# ...

# %%
# 2. Check the datatypes of your columns. 
citi_bike_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id           float64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
# 3. Convert the 'tripduration' column to datetime datatype.
citi_bike_df['tripduration'] = pd.to_datetime(citi_bike_df['tripduration'], unit='m')

# %%
# 4. Check the datatypes of your columns. 
citi_bike_df.dtypes
# Out:
# tripduration               datetime64[ns]
# starttime                          object
# stoptime                           object
# start station id                  float64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                    float64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                              int64
# dtype: object

# %%
citi_bike_df.head(5)
# Out:
#          tripduration                 starttime                  stoptime  \
# 0 1970-01-01 06:33:00  2019-08-01 00:00:01.4680  2019-08-01 00:06:35.3780
# 1 1970-01-01 10:27:00  2019-08-01 00:00:01.9290  2019-08-01 00:10:29.7840
# 2 1970-01-01 18:52:00  2019-08-01 00:00:04.0480  2019-08-01 00:18:56.1650
# 3 1970-01-02 05:40:00  2019-08-01 00:00:04.1630  2019-08-01 00:29:44.7940
# 4 1970-01-02 01:17:00  2019-08-01 00:00:05.4580  2019-08-01 00:25:23.4550
#
#    start station id              start station name  start station latitude  \
# 0             531.0          Forsyth St & Broome St               40.718939
# 1             274.0  Lafayette Ave & Fort Greene Pl               40.686919
# 2            2000.0        Front St & Washington St               40.702551
# 3             479.0                 9 Ave & W 45 St               40.760193
# 4            3312.0                 1 Ave & E 94 St               40.781721
#
# ...

# %%
# 5. Export the Dataframe as a new CSV file without the index.
citi_bike_df.to_csv(r'C:\Users\Admin\OneDrive\Data Analytics Bootcamp\Module 14 Tableau\bikesharing\citibike_tripdata.csv', index = False)
